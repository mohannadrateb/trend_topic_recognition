# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **Without normalizing**

# %%
pd_ai = pd.read_csv('ai_merged.csv')
pd_retweet = pd_ai[['date','retweet_count']] 
pd_follower_count = pd_ai[['date','follower_count']]
pd_likes = pd_ai[['date','favorite_count']]

# %%
plt.rcParams['figure.figsize'] = [10, 8]
pd_retweet.plot(label ="retweet_ai")
plt.xlabel('day',fontweight='bold')
plt.ylabel('NUM_OF_RETWEETS',fontweight='bold')


plt.legend()

# %%
pd_follower_count.plot(label = 'follower_count')
plt.xlabel('day',fontweight='bold')
plt.ylabel('NUM_OF_FOLLLOWERS',fontweight='bold')
plt.legend()

# %%
pd_likes.plot(label = 'number_of_likes')
plt.xlabel('day',fontweight='bold')
plt.ylabel('NUM_OF_LIKES',fontweight='bold')
plt.legend()

# %% [markdown]
# **CHANGING THE LIMITS**

# %%
pd_retweet.loc[pd_retweet.retweet_count > 50, 'retweet_count'] = 50
pd_retweet.plot(label ="retweet_ai")
plt.xlabel('day',fontweight='bold')
plt.ylabel('NUM_OF_RETWEETS',fontweight='bold')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# Text(0, 0.5, 'NUM_OF_RETWEETS')

# %%
pd_follower_count.loc[pd_follower_count.follower_count > 3, 'follower_count'] = 3
pd_follower_count.plot(label ="follower_count")
plt.xlabel('day',fontweight='bold')
plt.ylabel('NUM_OF_followers',fontweight='bold')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# Text(0, 0.5, 'NUM_OF_followers')

# %%
pd_likes.loc[pd_likes.favorite_count > 150, 'favorite_count'] = 150
pd_likes.plot(label ="LIKES")
plt.xlabel('day',fontweight='bold')
plt.ylabel('NUM_OF_LIKES',fontweight='bold')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# Text(0, 0.5, 'NUM_OF_LIKES')
